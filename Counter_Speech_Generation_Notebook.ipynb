# %% [markdown]
# # Counter-Speech Generation Notebook
#
# This notebook generates counter-speech responses from an input CSV file containing hate speech entries. You will be prompted to enter the file paths for both input and output. A progress bar will display the generation progress, and both the input and output files' contents will be shown.
#
# **Instructions**: Run each cell step-by-step. The output counter-speech responses will be saved to the specified file.

# %%
# !git clone https://github.com/Chryseisliu/Mandarin_Counter_Speech_Corpus
# Out:
# Cloning into 'Mandarin_Counter_Speech_Corpus'...
# remote: Enumerating objects: 262, done.
# remote: Counting objects: 100% (262/262), done.
# remote: Compressing objects: 100% (215/215), done.
# remote: Total 262 (delta 58), reused 230 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (262/262), 10.40 MiB | 11.17 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
# !cd Mandarin_Counter_Speech_Corpus&&git branch -a
# !cd Mandarin_Counter_Speech_Corpus && git checkout   remotes/origin/Filter
# Out:
# * main
#   remotes/origin/Filter
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/main
# Note: switching to 'remotes/origin/Filter'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 8c8f5a6 added outpt 4 and 7

# %%
# !mkdir split_output

# %%
# !cp -r Mandarin_Counter_Speech_Corpus/* Mandarin_Counter_Speech_Corpus/..

# %%
# !pip install -r requirements.txt
# !pip install tensorrt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 68.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from GeneratePossibleAnswers import GenerateAnswersFromCSV  # Adjust path as needed
from IPython.display import display
import os
from tqdm import tqdm
# Out:
# Model: BAAI/JudgeLM-7B-v1.0  has started loading!
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/598 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# ...

# %%
# Get file paths from user
input_csv_path = "split_input/filtered_hate_score_results_chunk_8.csv"
output_csv_path = "split_output/output_filtered_hate_score_results_chunk_8.csv"

# Load and display the output CSV to confirm generation
input_data = pd.read_csv(input_csv_path)
print("### Input CSV Preview ###")
display(input_data.head())
# Out:
# ### Input CSV Preview ###
#                                                 text  hate_score
# 0  他如果出不了国的话，确实亚裔被歧视和他没有一丁点关系。。。 人终归是自私的动物吧，许多对此义...        60.0
# 1  nigger源自negro（西班牙语意为黑色、黑人），本身是中立的词汇。但是在大量黑奴被贩卖...       100.0
# 2  虽然偶尔会觉得答主的犹太人阴谋论有点过火，不过这次恐怕还真是Neil Dickman 这个犹...        50.0
# 3  您是真的牛 我是真不明白 您这样的键盘侠 怎么把手也伸到知乎了 如果你觉得看不惯 来我回复评...        80.0
# 4  我就想问警察呢 这么大的骗局还举行比赛还去北京还一大堆监考一人一个还tm要家长钱还tm自己傻...        50.0

# %%
# Run the function and generate output
GenerateAnswersFromCSV(input_csv_path, output_csv_path,sampleSize=10,numAICallsPerAILoop=6,iterations=12)
# Out:
# Generating counter-speech:   0%|          | 0/50 [00:00<?, ?it/s][nltk_data] Downloading package udhr to /root/nltk_data...
# [nltk_data]   Unzipping corpora/udhr.zip.
# ...
# Total words in chinese corpus: 2884
# Filtered frequent words count: 512
# Word list saved to chinese_frequent_word_list.json
# Randomly selected client: Meta-Llama
# Randomly selected client: Meta-Llama-Large
# Randomly selected client: HermesRandomly selected client: Meta-Llama-Large
#
# Randomly selected client: Nous-Hermes-Mixtral
# Randomly selected client: Meta-Llama-Large
# Thread ThreadPoolExecutor-0_0 waiting for lock
# Thread ThreadPoolExecutor-0_0 acquired lock
# Thread ThreadPoolExecutor-0_0 is running get_model_answers
# ...
# 100%|██████████| 1/1 [00:02<00:00,  3.00s/it]
# Output1: 2.0, Output2: 1.0
# Thread ThreadPoolExecutor-0_0 released lock
# Thread ThreadPoolExecutor-0_0 waiting for lock
# Thread ThreadPoolExecutor-0_0 acquired lock
# Thread ThreadPoolExecutor-0_0 is running get_model_answers
# ...

# %%
# Load and display the output CSV to confirm generation
output_data = pd.read_csv(output_csv_path)
print("### Output CSV Preview ###")
display(output_data.head())

print(f"Counter-speech responses generated and saved to {output_csv_path}")
